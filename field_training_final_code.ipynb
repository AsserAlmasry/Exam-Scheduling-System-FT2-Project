# %%
import csv
import collections
import random as rn
from numpy import concatenate
from numpy import random
from numpy.random import randint
import copy


days = [("Saturday", 0), ("Sunday", 1), ("Monday", 2), ("Tuesday", 3), ("Wednesday", 4),
        ("Thursday", 5), ("Saturday", 6), ("Sunday", 7), ("Monday", 8), ("Tuesday", 9), ("Wednesday", 10), ("Thursday", 11)]
totalDays = len(days)
examStartTimings = [(12, 0), (3, 1)]
totalExamStartTimings = len(examStartTimings)
examDuration = 3
courses = []
instructors = []
totalInstructors = -1
registrations = []
Individual = collections.namedtuple('Population', 'chromosome value')
population_size = 0
crossover_probability, mutation_probability = 0.0, 0.0
MG_indexes = []
CS_indexes = []
classRooms = []


# Class to store course
class Course:
    # Initialize the class
    def __init__(self, code, name, number):
        self.courseCode = code
        self.courseName = name
        self.number = number

    # Print course
    def __repr__(self):
        return '({0},{1},{2})'.format(self.courseCode, self.courseName, self.number)

    # Check Equality
    def __eq__(self, other):
        return self.courseName == other.courseName and self.courseCode == other.courseCode


# Class to store student registered in course
class Registration:
    # Initialize the class
    def __init__(self, Name, courseCodes):
        self.studentName = Name
        self.registeredCourses = courseCodes.copy()

    # Print registration
    def __repr__(self):
        return '({0},{1})'.format(self.studentName, self.registeredCourses)

    # Check equality
    def __eq__(self, other):
        if self.studentName == other.studentName and len(self.registeredCourses) == len(other.registeredCourses):
            count = 0
            for i in range(len(self.registeredCourses)):
                if self.registeredCourses[i] == other.registeredCourses[i]:
                    count += 1
            if count == len(self.registeredCourses):
                return True
        return False


# Class to store an exam
class Exam:
    # Initialize the class
    def __init__(self, startTime, roomNo, day, invigilators):
        self.startTime = startTime
        self.roomNo = roomNo.copy()
        self.day = day
        self.invigilators = invigilators.copy()
        self.binary = []

    # Print an exam
    def __repr__(self):
        return '(\n{0}, {1}, {2}, {3}), \n{4}'.format(self.startTime,
                                                      self.roomNo, self.day, self.invigilators, self.binary)

    # Check equality
    def __eq__(self, other):
        if len(self.roomNo) == len(other.roomNo) and self.startTime == other.startTime and self.day == other.day \
                and len(self.invigilators) == len(other.invigilators):
            count = 0
            count1 = 0
            for i in range(len(self.roomNo)):
                if self.roomNo[i] == other.roomNo[i]:
                    count += 1
            for i in range(len(self.invigilators)):
                if self.invigilators[i] == other.invigilators[i]:
                    count1 += 1
            if count == len(self.roomNo) and count1 == len(self.invigilators):
                return True
        return False


# Reading from files
def takeInput():
    global totalInstructors, instructors, classRooms, course_doctors, part_time_doctors

    # Reading courses from file
    with open('courses.csv') as file:
        reader = csv.reader(file)
        count = 0
        for row in reader:
            if len(row) != 0:
                temp_course = Course(row[0], row[1], count)
                if temp_course not in courses:
                    courses.append(temp_course)
                    count += 1

    # Reading instructors from file
    with open('teachers.csv') as file:
        reader = csv.reader(file)
        count = 0
        for row in reader:
            if len(row) != 0:
                check = False
                for instructor in instructors:
                    if instructor[0] == row[0]:
                        check = True
                        break
                if not check:
                    instructors.append((row[0], count, row[2]))
                    count += 1

    totalInstructors = len(instructors)

    # Reading courses taught by each instructor from file
    course_doctors = {}
    part_time_doctors = []
    with open('teachers.csv') as file:
        reader = csv.reader(file)
        next(reader)  # Skip the header row
        for row in reader:
            if len(row) != 0:
                doctor = row[0]
                course = row[1]
                status = row[2]
                course_doctors[course] = doctor
                if status == 'PartTime':
                    part_time_doctors.append(doctor)

    # Reading students from file
    with open('studentNames.csv') as file:
        reader = csv.reader(file)
        for row in reader:
            if len(row) != 0:
                temp_registration = Registration(row[0], [])
                if temp_registration not in registrations:
                    registrations.append(temp_registration)

    # Reading registrations of students from file
    with open('studentCourse.csv') as file:
        reader = csv.reader(file)
        for row in reader:
            if len(row) != 0 and row[0] != '':
                for i in registrations:
                    if i.studentName == row[1] and row[2] not in i.registeredCourses:
                        i.registeredCourses.append(row[2])

    # Reading classrooms from file
    with open('classRooms.csv') as file:
        reader = csv.reader(file)
        next(reader)  # Skip the header row
        for row in reader:
            if len(row) != 0:
                index, room, capacity = row
                capacity = int(capacity)
                classRooms.append((room, capacity))


# Generate random exam with two invigilators per room
def getRandomExam(index):
    courseCode = courses[index].courseCode
    students = [x for x in registrations if courseCode in x.registeredCourses]
    total_students = len(students)

    # Assigning rooms required to accommodate all students
    roomNo = []
    totalClassRooms = len(classRooms)
    classRooms.sort(key=lambda x: x[1], reverse=True)
    while total_students > 0:
        if total_students > classRooms[0][1]:
            roomNo.append(classRooms[0])
            total_students -= classRooms[0][1]
        else:
            temp = rn.choice([room for room in classRooms if room[1] >= total_students])
            roomNo.append(temp)
            total_students -= temp[1]

    # Setting time
    startTime = examStartTimings[rn.randrange(0, totalExamStartTimings)]
    if startTime[0] > 12:
        startTime -= 12

    # Setting day
    day = days[rn.randrange(0, totalDays)]

    # Assigning invigilators required to invigilate all rooms
    invigilators = []
    doctor = next(filter(lambda x: x[0] == course_doctors[courseCode], instructors))
    invigilators.append(doctor)  # Doctor of the course is always one of the invigilators

    if doctor[2] == 'PartTime':
        # If the doctor is part-time, choose a full-time invigilator for the second slot
        full_time_invigilators = [instructor for instructor in instructors if instructor[2] == 'FullTime']
        invigilator = rn.choice(full_time_invigilators)
        invigilators.append(invigilator)
    else:
        # If the doctor is full-time, choose any random invigilator for the second slot
        for i in range(1):
            invigilator = rn.choice(instructors)
            while invigilator == doctor or invigilator[2] == 'PartTime':
                invigilator = rn.choice(instructors)
            invigilators.append(invigilator)

    return Exam(startTime, roomNo, day, invigilators)



# Generate Population, given the size
def generate_population(size):
    new_population = []

    # Initialize Random population
    for i in range(size):
        timeTable = []
        for j in range(len(courses)):
            timeTable.append(getRandomExam(j))

        new_population.append(
            Individual(
                chromosome=timeTable,
                value=-1
            )
        )
    return new_population


# Apply Mutation on chromosomes
def apply_mutation(chromosome):
    if random.randint(0, 100) <= mutation_probability * 100:
        gene = random.randint(0, len(courses) - 1)
        chromosome[gene] = getRandomExam(gene)
    return chromosome


# Apply Crossover on population
def apply_crossover(population):
    crossover_population = []

    while len(crossover_population) < len(population):
        if randint(0, 100) <= crossover_probability * 100:
            # Selecting parents
            parent_a = randint(0, len(population) - 1)
            parent_b = randint(0, len(population) - 1)

            # Doing crossover
            chromosome_a = copy.deepcopy(concatenate((population[parent_a].chromosome[:int(len(courses) / 2)],
                                                      population[parent_b].chromosome[int(len(courses) / 2):])))
            chromosome_a = apply_mutation(chromosome_a)

            chromosome_b = copy.deepcopy(concatenate((population[parent_b].chromosome[:int(len(courses) / 2)],
                                                      population[parent_a].chromosome[int(len(courses) / 2):])))
            chromosome_b = apply_mutation(chromosome_b)

            crossover_population.append(Individual(
                chromosome=chromosome_a,
                value=-1
            ))
            crossover_population.append(Individual(
                chromosome=chromosome_b,
                value=-1
            ))

    # Calculating fitness of crossover population
    crossover_population = calculate_fitness(crossover_population)
    # Combining will all population
    population = population + crossover_population
    return population


# Roulette Wheel Selection
def roulette_wheel_selection(population):
    # Calculating total fitness
    population_fitness = sum([individual.value for individual in population])
    # Calculating probabilities of all chromosomes
    chromosome_probabilities = [round(individual.value / population_fitness, 5) for individual in population]

    copy_probabilities = chromosome_probabilities.copy()
    copy_probabilities.sort()
    for i in range(len(copy_probabilities)):
        if i != 0:
            copy_probabilities[i] = round(copy_probabilities[i] + copy_probabilities[i - 1], 5)

    # Selecting population
    selected_population = []
    for i in range(population_size):
        index = -1
        random_probability = round(random.uniform(0, 1), 5)
        for j in range(len(copy_probabilities)):
            if random_probability <= copy_probabilities[j]:
                value = copy_probabilities[j]
                if j != 0:
                    value = round(value - copy_probabilities[j - 1], 5)
                index = chromosome_probabilities.index(value)
                break
        selected_population.append(population[index])
    return selected_population


# Find Top Fittest Individual from Population
def find_fittest_individual(population):
    highest_value = 0
    highest_index = 0
    for i in range(len(population)):
        if population[i].value > highest_value:
            highest_value = population[i].value
            highest_index = i
    return population[highest_index]


# Checks whether same invigilator invigilating exams at the same time or not
def checkInvigilation(chromosome):
    violation_count = 0
    data = [(individual.invigilators, individual.day, individual.startTime) for individual in chromosome]
    for i in range(len(data)):
        for invigilator in data[i][0]:
            for j in range(len(data)):
                if i != j and invigilator in data[j][0] and data[i][1] == data[j][1] and data[i][2] == data[j][2]:
                    violation_count += 1
    return violation_count // 2



# Checks whether an exam at the same time is scheduled in the same room or not
def checkRooms(chromosome):
    violation_count = 0
    for gene in chromosome:
        for room in gene.roomNo:
            for gene1 in chromosome:
                for room1 in gene1.roomNo:
                    if gene != gene1:
                        if room == room1 and gene.day == gene1.day and gene.startTime == gene1.startTime:
                            violation_count += 1
    return violation_count // 2


# Checks whether an invigilator is invigilating two exams in a row or not
def checkInvigilatorBreak(chromosome):
    violation_count = 0
    data = [(individual.invigilators, individual.day) for individual in chromosome]

    for i in range(len(data)):
        for invigilator in data[i][0]:
            for j in range(len(data)):
                if i != j and invigilator in data[j][0] and data[i][1] == data[j][1]:
                    violation_count += 1
    return violation_count // 2



# Checks whether the student is giving one exam at a time or not
def one_exam_student_check(chromosome):
    violation_count = 0
    for i in range(0, len(registrations)):
        days_arr = []
        for j in range(0, len(chromosome)):
            if courses[j].courseCode in registrations[i].registeredCourses:
                if (chromosome[j].day[1], chromosome[j].startTime) not in days_arr:
                    days_arr.append((chromosome[j].day[1], chromosome[j].startTime))
                else:
                    violation_count += 1
    return violation_count


# Checks whether MG course exam is before CS course exam or not
def check_MGCS(chromosome):
    for i in range(0, len(registrations)):
        for j in MG_indexes:
            if courses[j].courseCode in registrations[i].registeredCourses:
                for k in CS_indexes:
                    if courses[k].courseCode in registrations[i].registeredCourses:
                        CS_day = chromosome[k].day[1]
                        MG_day = chromosome[j].day[1]
                        if CS_day < MG_day:
                            chromosome[k].day, chromosome[j].day = chromosome[j].day, chromosome[k].day
                        if CS_day == MG_day and chromosome[k].startTime[1] < chromosome[j].startTime[1]:
                            chromosome[k].startTime, chromosome[j].startTime = \
                                chromosome[j].startTime, chromosome[k].startTime
    return 0


# Calculating fitness of given chromosome
def calculate_value(chromosome):
    value = 400
    value -= check_MGCS(chromosome)
    value -= checkInvigilation(chromosome)
    value -= checkRooms(chromosome)
    value -= checkInvigilatorBreak(chromosome)
    value -= one_exam_student_check(chromosome)

    # Binary encoding
    for i in range(len(chromosome)):
        chromosome[i].binary.clear()
        chromosome[i].binary.append(bin(courses[i].number)[2:].zfill(6))
        chromosome[i].binary.append(bin(chromosome[i].startTime[1])[2:].zfill(6))
        tempRoom = []
        for room in chromosome[i].roomNo:
            tempRoom.append(bin(room[1])[2:].zfill(6))
        chromosome[i].binary.append(tempRoom)
        chromosome[i].binary.append(bin(chromosome[i].day[1])[2:].zfill(6))
        tempInvigilator = []
        for invigilator in chromosome[i].invigilators:  # Fixed attribute name
            tempInvigilator.append(bin(invigilator[1])[2:].zfill(6))
        chromosome[i].binary.append(tempInvigilator)
    return value



# Assigning fitness to the chromosomes in population
def calculate_fitness(population):
    for i in range(len(population)):
        v = calculate_value(population[i].chromosome)
        population[i] = Individual(
            chromosome=population[i].chromosome,
            value=v
        )
    return population


# Displays the schedule
def display_schedule(best_solution):
    count = 0
    temp_day = -1

    week = 1
    last_week_entry = 0
    weekflag = False

    max_invigilator_length = max(len(invigilator[0]) for invigilator in instructors)

    max_length = max(len(course.courseName) for course in courses)

    best_solution_copy = copy.deepcopy(best_solution)
    best_solution_copy = Individual(sorted(best_solution_copy.chromosome, key=lambda x: (x.day[1], x.startTime[1])),
                                    best_solution_copy.value)

    print("\n\nSCHEDULE:\n--------")
    for i in best_solution_copy.chromosome:
        curr_day = i.day[1]
        if curr_day >= last_week_entry:
            if count != 0:
                print(end="\t\t")
                for j in range(0, 41 + max_length + 2 * max_invigilator_length):
                    print(end="-")
                print()

            print("\nWeek", week)
            print("------")
            week += 1
            last_week_entry += 6
            weekflag = True

        if temp_day != curr_day:
            if count != 0 and weekflag == False:
                print(end="\t\t")
                for j in range(0, 41 + max_length + 2 * max_invigilator_length):
                    print(end="-")
                print()

            print(end="\n\t\t")
            print(i.day[0])
            weekflag = False

        print(end="\t\t")
        for j in range(0, 41 + max_length + 2 * max_invigilator_length):
            print(end="-")
        print()

        print(end="\t\t")
        for j in range(0, len(courses)):
            if best_solution.chromosome[j] == i:
                ind = j
                break
        print("|", courses[ind].courseCode, "|", courses[ind].courseName, end="")

        if len(courses[ind].courseCode) == 5:
            for j in range(0, max_length - len(courses[ind].courseName)):
                print(end=" ")
        else:
            for j in range(0, max_length - len(courses[ind].courseName) - 1):
                print(end=" ")
        print(end=" | ")

        if i.startTime[1] == 0:
            print(end="12:00 AM | ")
        else:
            print(end="3:00 PM | ")

        for j in range(0, len(i.roomNo)):
            if j != 0:
                print(end="\t\t")
                for k in range(0, 23 + max_length):
                    print(end=" ")

            print("Room", j + 1, end="")
            print(":", i.roomNo[j][0], "|", i.invigilators[2 * j][0], ",", i.invigilators[2 * j + 1][0], end="")
            for k in range(0, max_invigilator_length - max(len(i.invigilators[2 * j][0]), len(i.invigilators[2 * j + 1][0])) + 1):
                print(end=" ")
            print("|")

        temp_day = curr_day
        count += 1

    print(end="\t\t")
    for j in range(0, 41 + max_length + 2 * max_invigilator_length):
        print(end="-")
    print()



# Run Complete Algorithm Step by step
def runGA():
    # Generating random population
    population = generate_population(population_size)
    generation = 1
    best_solution = None

    # Calculate Fitness of initial population
    population = calculate_fitness(population)

    # Running generations
    while True:
        # Applying crossover and mutation
        population = apply_crossover(population)
        # Selection using roulette wheel
        population = roulette_wheel_selection(population)
        # Finding fittest candidates
        candidate = find_fittest_individual(population)

        # Updating best solution so far
        if best_solution is None:
            best_solution = candidate
        elif candidate.value > best_solution.value:
            best_solution = candidate

        # print Every 10th generation results
        if generation % 10 == 0 or generation == 1:
            print('\nCurrent generation: {}'.format(generation))
            print('Best solution so far: {}, Goal: 400'.format(best_solution.value))

        # break when solution is found
        if best_solution.value == 400:
            print('\nSolution found:')
            print('Value: {}, Goal: 400'.format(best_solution.value))

            print("\nHard Constraints:")
            print("1: An exam will be scheduled for each course\t\t\t\t ✔")
            print("2: A student is enrolled in minimum three courses\t\t\t ✔")
            if one_exam_student_check(best_solution.chromosome) == 0:
                print("3: A student can not give more than one exam at a time\t\t\t ✔")
            else:
                print("3: A student can not give more than one exam at a time\t\t\t ❌")
            print("4: All exams must be held between 9 AM and 5 PM\t\t\t\t ✔")
            if checkInvigilation(best_solution.chromosome) == 0:
                print("5: A teacher can not invigilate two exams at the same time\t\t ✔")
            else:
                print("5: A teacher can not invigilate two exams at the same time\t\t ❌")
            if checkInvigilatorBreak(best_solution.chromosome) == 0:
                print("6: A teacher can not invigilate two exams in a row\t\t\t ✔")
            else:
                print("6: A teacher can not invigilate two exams in a row\t\t\t ❌")
            if checkRooms(best_solution.chromosome) == 0:
                print("7: No exam scheduled in the same room at the same time\t\t\t ✔")
            else:
                print("7: No exam scheduled in the same room at the same time\t\t\t ❌")

            print("\nSoft Constraints:")
            print("1: An exam will be scheduled for each course\t\t\t\t ✔")
            print("2: A student shall not give more than one exam consecutively\t\t ✔")
            print("3: MG courses preferably be held before CS courses\t\t\t ✔")
            print("4: Two hours of break for faculty meeting\t\t\t\t ✔")

            display_schedule(best_solution)
            break
        generation += 1


if __name__ == "__main__":
    # Taking input from files
    takeInput()

    # Initializing population size and Crossover and Mutation Probabilities
    population_size = random.randint(50, 150)
    crossover_probability = round(random.uniform(low=0.3, high=1.0), 1)
    mutation_probability = round(random.uniform(low=0.0, high=0.5), 1)

    # Calculating MG and CS courses indexes
    for i in range(0, len(courses)):
        if courses[i].courseCode[0] == 'M' and courses[i].courseCode[1] == 'G':
            MG_indexes.append(i)
        if courses[i].courseCode[0] == 'C' and courses[i].courseCode[1] == 'S':
            CS_indexes.append(i)

    # Printing Initialized variables
    print('----- Generated Parameters -----')
    print('Population size......: {}'.format(population_size))
    print('Crossover probability: {}'.format(crossover_probability))
    print('Mutation probability.: {}'.format(mutation_probability))

    # Running Genetic Algorithm
    runGA()
# Out:
# Streaming output truncated to the last 5000 lines.
# Best solution so far: 399, Goal: 400
#
# Current generation: 2500
# Best solution so far: 399, Goal: 400
#
# Current generation: 2510
# Best solution so far: 399, Goal: 400
#
# Current generation: 2520
# Best solution so far: 399, Goal: 400
#
# Current generation: 2530
# Best solution so far: 399, Goal: 400
#
# Current generation: 2540
# Best solution so far: 399, Goal: 400
#
# Current generation: 2550
# Best solution so far: 399, Goal: 400
#
# Current generation: 2560
# Best solution so far: 399, Goal: 400
#
# Current generation: 2570
# Best solution so far: 399, Goal: 400
#
# Current generation: 2580
# Best solution so far: 399, Goal: 400
#
# Current generation: 2590
# Best solution so far: 399, Goal: 400
#
# Current generation: 2600
# Best solution so far: 399, Goal: 400
#
# Current generation: 2610
# Best solution so far: 399, Goal: 400
#
# Current generation: 2620
# Best solution so far: 399, Goal: 400
#
# Current generation: 2630
# Best solution so far: 399, Goal: 400
#
# Current generation: 2640
# Best solution so far: 399, Goal: 400
#
# Current generation: 2650
# Best solution so far: 399, Goal: 400
#
# Current generation: 2660
# Best solution so far: 399, Goal: 400
#
# Current generation: 2670
# Best solution so far: 399, Goal: 400
#
# Current generation: 2680
# Best solution so far: 399, Goal: 400
#
# Current generation: 2690
# Best solution so far: 399, Goal: 400
#
# Current generation: 2700
# Best solution so far: 399, Goal: 400
#
# Current generation: 2710
# Best solution so far: 399, Goal: 400
#
# Current generation: 2720
# Best solution so far: 399, Goal: 400
#
# Current generation: 2730
# Best solution so far: 399, Goal: 400
#
# Current generation: 2740
# Best solution so far: 399, Goal: 400
#
# Current generation: 2750
# Best solution so far: 399, Goal: 400
#
# Current generation: 2760
# Best solution so far: 399, Goal: 400
#
# Current generation: 2770
# Best solution so far: 399, Goal: 400
#
# Current generation: 2780
# Best solution so far: 399, Goal: 400
#
# Current generation: 2790
# Best solution so far: 399, Goal: 400
#
# Current generation: 2800
# Best solution so far: 399, Goal: 400
#
# Current generation: 2810
# Best solution so far: 399, Goal: 400
#
# Current generation: 2820
# Best solution so far: 399, Goal: 400
#
# Current generation: 2830
# Best solution so far: 399, Goal: 400
#
# Current generation: 2840
# Best solution so far: 399, Goal: 400
#
# Current generation: 2850
# Best solution so far: 399, Goal: 400
#
# Current generation: 2860
# Best solution so far: 399, Goal: 400
#
# Current generation: 2870
# Best solution so far: 399, Goal: 400
#
# Current generation: 2880
# Best solution so far: 399, Goal: 400
#
# Current generation: 2890
# Best solution so far: 399, Goal: 400
#
# Current generation: 2900
# Best solution so far: 399, Goal: 400
#
# Current generation: 2910
# Best solution so far: 399, Goal: 400
#
# Current generation: 2920
# Best solution so far: 399, Goal: 400
#
# Current generation: 2930
# Best solution so far: 399, Goal: 400
#
# Current generation: 2940
# Best solution so far: 399, Goal: 400
#
# Current generation: 2950
# Best solution so far: 399, Goal: 400
#
# Current generation: 2960
# Best solution so far: 399, Goal: 400
#
# Current generation: 2970
# Best solution so far: 399, Goal: 400
#
# Current generation: 2980
# Best solution so far: 399, Goal: 400
#
# Current generation: 2990
# Best solution so far: 399, Goal: 400
#
# Current generation: 3000
# Best solution so far: 399, Goal: 400
#
# Current generation: 3010
# Best solution so far: 399, Goal: 400
#
# Current generation: 3020
# Best solution so far: 399, Goal: 400
#
# Current generation: 3030
# Best solution so far: 399, Goal: 400
#
# Current generation: 3040
# Best solution so far: 399, Goal: 400
#
# Current generation: 3050
# Best solution so far: 399, Goal: 400
#
# Current generation: 3060
# Best solution so far: 399, Goal: 400
#
# Current generation: 3070
# Best solution so far: 399, Goal: 400
#
# Current generation: 3080
# Best solution so far: 399, Goal: 400
#
# Current generation: 3090
# Best solution so far: 399, Goal: 400
#
# Current generation: 3100
# Best solution so far: 399, Goal: 400
#
# Current generation: 3110
# Best solution so far: 399, Goal: 400
#
# Current generation: 3120
# Best solution so far: 399, Goal: 400
#
# Current generation: 3130
# Best solution so far: 399, Goal: 400
#
# Current generation: 3140
# Best solution so far: 399, Goal: 400
#
# Current generation: 3150
# Best solution so far: 399, Goal: 400
#
# Current generation: 3160
# Best solution so far: 399, Goal: 400
#
# Current generation: 3170
# Best solution so far: 399, Goal: 400
#
# Current generation: 3180
# Best solution so far: 399, Goal: 400
#
# Current generation: 3190
# Best solution so far: 399, Goal: 400
#
# Current generation: 3200
# Best solution so far: 399, Goal: 400
#
# Current generation: 3210
# Best solution so far: 399, Goal: 400
#
# Current generation: 3220
# Best solution so far: 399, Goal: 400
#
# Current generation: 3230
# Best solution so far: 399, Goal: 400
#
# Current generation: 3240
# Best solution so far: 399, Goal: 400
#
# Current generation: 3250
# Best solution so far: 399, Goal: 400
#
# Current generation: 3260
# Best solution so far: 399, Goal: 400
#
# Current generation: 3270
# Best solution so far: 399, Goal: 400
#
# Current generation: 3280
# Best solution so far: 399, Goal: 400
#
# Current generation: 3290
# Best solution so far: 399, Goal: 400
#
# Current generation: 3300
# Best solution so far: 399, Goal: 400
#
# Current generation: 3310
# Best solution so far: 399, Goal: 400
#
# Current generation: 3320
# Best solution so far: 399, Goal: 400
#
# Current generation: 3330
# Best solution so far: 399, Goal: 400
#
# Current generation: 3340
# Best solution so far: 399, Goal: 400
#
# Current generation: 3350
# Best solution so far: 399, Goal: 400
#
# Current generation: 3360
# Best solution so far: 399, Goal: 400
#
# Current generation: 3370
# Best solution so far: 399, Goal: 400
#
# Current generation: 3380
# Best solution so far: 399, Goal: 400
#
# Current generation: 3390
# Best solution so far: 399, Goal: 400
#
# Current generation: 3400
# Best solution so far: 399, Goal: 400
#
# Current generation: 3410
# Best solution so far: 399, Goal: 400
#
# Current generation: 3420
# Best solution so far: 399, Goal: 400
#
# Current generation: 3430
# Best solution so far: 399, Goal: 400
#
# Current generation: 3440
# Best solution so far: 399, Goal: 400
#
# Current generation: 3450
# Best solution so far: 399, Goal: 400
#
# Current generation: 3460
# Best solution so far: 399, Goal: 400
#
# Current generation: 3470
# Best solution so far: 399, Goal: 400
#
# Current generation: 3480
# Best solution so far: 399, Goal: 400
#
# Current generation: 3490
# Best solution so far: 399, Goal: 400
#
# Current generation: 3500
# Best solution so far: 399, Goal: 400
#
# Current generation: 3510
# Best solution so far: 399, Goal: 400
#
# Current generation: 3520
# Best solution so far: 399, Goal: 400
#
# Current generation: 3530
# Best solution so far: 399, Goal: 400
#
# Current generation: 3540
# Best solution so far: 399, Goal: 400
#
# Current generation: 3550
# Best solution so far: 399, Goal: 400
#
# Current generation: 3560
# Best solution so far: 399, Goal: 400
#
# Current generation: 3570
# Best solution so far: 399, Goal: 400
#
# Current generation: 3580
# Best solution so far: 399, Goal: 400
#
# Current generation: 3590
# Best solution so far: 399, Goal: 400
#
# Current generation: 3600
# Best solution so far: 399, Goal: 400
#
# Current generation: 3610
# Best solution so far: 399, Goal: 400
#
# Current generation: 3620
# Best solution so far: 399, Goal: 400
#
# Current generation: 3630
# Best solution so far: 399, Goal: 400
#
# Current generation: 3640
# Best solution so far: 399, Goal: 400
#
# Current generation: 3650
# Best solution so far: 399, Goal: 400
#
# Current generation: 3660
# Best solution so far: 399, Goal: 400
#
# Current generation: 3670
# Best solution so far: 399, Goal: 400
#
# Current generation: 3680
# Best solution so far: 399, Goal: 400
#
# Current generation: 3690
# Best solution so far: 399, Goal: 400
#
# Current generation: 3700
# Best solution so far: 399, Goal: 400
#
# Current generation: 3710
# Best solution so far: 399, Goal: 400
#
# Current generation: 3720
# Best solution so far: 399, Goal: 400
#
# Current generation: 3730
# Best solution so far: 399, Goal: 400
#
# Current generation: 3740
# Best solution so far: 399, Goal: 400
#
# Current generation: 3750
# Best solution so far: 399, Goal: 400
#
# Current generation: 3760
# Best solution so far: 399, Goal: 400
#
# Current generation: 3770
# Best solution so far: 399, Goal: 400
#
# Current generation: 3780
# Best solution so far: 399, Goal: 400
#
# Current generation: 3790
# Best solution so far: 399, Goal: 400
#
# Current generation: 3800
# Best solution so far: 399, Goal: 400
#
# Current generation: 3810
# Best solution so far: 399, Goal: 400
#
# Current generation: 3820
# Best solution so far: 399, Goal: 400
#
# Current generation: 3830
# Best solution so far: 399, Goal: 400
#
# Current generation: 3840
# Best solution so far: 399, Goal: 400
#
# Current generation: 3850
# Best solution so far: 399, Goal: 400
#
# Current generation: 3860
# Best solution so far: 399, Goal: 400
#
# Current generation: 3870
# Best solution so far: 399, Goal: 400
#
# Current generation: 3880
# Best solution so far: 399, Goal: 400
#
# Current generation: 3890
# Best solution so far: 399, Goal: 400
#
# Current generation: 3900
# Best solution so far: 399, Goal: 400
#
# Current generation: 3910
# Best solution so far: 399, Goal: 400
#
# Current generation: 3920
# Best solution so far: 399, Goal: 400
#
# Current generation: 3930
# Best solution so far: 399, Goal: 400
#
# Current generation: 3940
# Best solution so far: 399, Goal: 400
#
# Current generation: 3950
# Best solution so far: 399, Goal: 400
#
# Current generation: 3960
# Best solution so far: 399, Goal: 400
#
# Current generation: 3970
# Best solution so far: 399, Goal: 400
#
# Current generation: 3980
# Best solution so far: 399, Goal: 400
#
# Current generation: 3990
# Best solution so far: 399, Goal: 400
#
# Current generation: 4000
# Best solution so far: 399, Goal: 400
#
# Current generation: 4010
# Best solution so far: 399, Goal: 400
#
# Current generation: 4020
# Best solution so far: 399, Goal: 400
#
# Current generation: 4030
# Best solution so far: 399, Goal: 400
#
# Current generation: 4040
# Best solution so far: 399, Goal: 400
#
# Current generation: 4050
# Best solution so far: 399, Goal: 400
#
# Current generation: 4060
# Best solution so far: 399, Goal: 400
#
# Current generation: 4070
# Best solution so far: 399, Goal: 400
#
# Current generation: 4080
# Best solution so far: 399, Goal: 400
#
# Current generation: 4090
# Best solution so far: 399, Goal: 400
#
# Current generation: 4100
# Best solution so far: 399, Goal: 400
#
# Current generation: 4110
# Best solution so far: 399, Goal: 400
#
# Current generation: 4120
# Best solution so far: 399, Goal: 400
#
# Current generation: 4130
# Best solution so far: 399, Goal: 400
#
# Current generation: 4140
# Best solution so far: 399, Goal: 400
#
# Current generation: 4150
# Best solution so far: 399, Goal: 400
#
# Current generation: 4160
# Best solution so far: 399, Goal: 400
#
# Current generation: 4170
# Best solution so far: 399, Goal: 400
#
# Current generation: 4180
# Best solution so far: 399, Goal: 400
#
# Current generation: 4190
# Best solution so far: 399, Goal: 400
#
# Current generation: 4200
# Best solution so far: 399, Goal: 400
#
# Current generation: 4210
# Best solution so far: 399, Goal: 400
#
# Current generation: 4220
# Best solution so far: 399, Goal: 400
#
# Current generation: 4230
# Best solution so far: 399, Goal: 400
#
# Current generation: 4240
# Best solution so far: 399, Goal: 400
#
# Current generation: 4250
# Best solution so far: 399, Goal: 400
#
# Current generation: 4260
# Best solution so far: 399, Goal: 400
#
# Current generation: 4270
# Best solution so far: 399, Goal: 400
#
# Current generation: 4280
# Best solution so far: 399, Goal: 400
#
# Current generation: 4290
# Best solution so far: 399, Goal: 400
#
# Current generation: 4300
# Best solution so far: 399, Goal: 400
#
# Current generation: 4310
# Best solution so far: 399, Goal: 400
#
# Current generation: 4320
# Best solution so far: 399, Goal: 400
#
# Current generation: 4330
# Best solution so far: 399, Goal: 400
#
# Current generation: 4340
# Best solution so far: 399, Goal: 400
#
# Current generation: 4350
# Best solution so far: 399, Goal: 400
#
# Current generation: 4360
# Best solution so far: 399, Goal: 400
#
# Current generation: 4370
# Best solution so far: 399, Goal: 400
#
# Current generation: 4380
# Best solution so far: 399, Goal: 400
#
# Current generation: 4390
# Best solution so far: 399, Goal: 400
#
# Current generation: 4400
# Best solution so far: 399, Goal: 400
#
# Current generation: 4410
# Best solution so far: 399, Goal: 400
#
# Current generation: 4420
# Best solution so far: 399, Goal: 400
#
# Current generation: 4430
# Best solution so far: 399, Goal: 400
#
# Current generation: 4440
# Best solution so far: 399, Goal: 400
#
# Current generation: 4450
# Best solution so far: 399, Goal: 400
#
# Current generation: 4460
# Best solution so far: 399, Goal: 400
#
# Current generation: 4470
# Best solution so far: 399, Goal: 400
#
# Current generation: 4480
# Best solution so far: 399, Goal: 400
#
# Current generation: 4490
# Best solution so far: 399, Goal: 400
#
# Current generation: 4500
# Best solution so far: 399, Goal: 400
#
# Current generation: 4510
# Best solution so far: 399, Goal: 400
#
# Current generation: 4520
# Best solution so far: 399, Goal: 400
#
# Current generation: 4530
# Best solution so far: 399, Goal: 400
#
# Current generation: 4540
# Best solution so far: 399, Goal: 400
#
# Current generation: 4550
# Best solution so far: 399, Goal: 400
#
# Current generation: 4560
# Best solution so far: 399, Goal: 400
#
# Current generation: 4570
# Best solution so far: 399, Goal: 400
#
# Current generation: 4580
# Best solution so far: 399, Goal: 400
#
# Current generation: 4590
# Best solution so far: 399, Goal: 400
#
# Current generation: 4600
# Best solution so far: 399, Goal: 400
#
# Current generation: 4610
# Best solution so far: 399, Goal: 400
#
# Current generation: 4620
# Best solution so far: 399, Goal: 400
#
# Current generation: 4630
# Best solution so far: 399, Goal: 400
#
# Current generation: 4640
# Best solution so far: 399, Goal: 400
#
# Current generation: 4650
# Best solution so far: 399, Goal: 400
#
# Current generation: 4660
# Best solution so far: 399, Goal: 400
#
# Current generation: 4670
# Best solution so far: 399, Goal: 400
#
# Current generation: 4680
# Best solution so far: 399, Goal: 400
#
# Current generation: 4690
# Best solution so far: 399, Goal: 400
#
# Current generation: 4700
# Best solution so far: 399, Goal: 400
#
# Current generation: 4710
# Best solution so far: 399, Goal: 400
#
# Current generation: 4720
# Best solution so far: 399, Goal: 400
#
# Current generation: 4730
# Best solution so far: 399, Goal: 400
#
# Current generation: 4740
# Best solution so far: 399, Goal: 400
#
# Current generation: 4750
# Best solution so far: 399, Goal: 400
#
# Current generation: 4760
# Best solution so far: 399, Goal: 400
#
# Current generation: 4770
# Best solution so far: 399, Goal: 400
#
# Current generation: 4780
# Best solution so far: 399, Goal: 400
#
# Current generation: 4790
# Best solution so far: 399, Goal: 400
#
# Current generation: 4800
# Best solution so far: 399, Goal: 400
#
# Current generation: 4810
# Best solution so far: 399, Goal: 400
#
# Current generation: 4820
# Best solution so far: 399, Goal: 400
#
# Current generation: 4830
# Best solution so far: 399, Goal: 400
#
# Current generation: 4840
# Best solution so far: 399, Goal: 400
#
# Current generation: 4850
# Best solution so far: 399, Goal: 400
#
# Current generation: 4860
# Best solution so far: 399, Goal: 400
#
# Current generation: 4870
# Best solution so far: 399, Goal: 400
#
# Current generation: 4880
# Best solution so far: 399, Goal: 400
#
# Current generation: 4890
# Best solution so far: 399, Goal: 400
#
# Current generation: 4900
# Best solution so far: 399, Goal: 400
#
# Current generation: 4910
# Best solution so far: 399, Goal: 400
#
# Current generation: 4920
# Best solution so far: 399, Goal: 400
#
# Current generation: 4930
# Best solution so far: 399, Goal: 400
#
# Current generation: 4940
# Best solution so far: 399, Goal: 400
#
# Current generation: 4950
# Best solution so far: 399, Goal: 400
#
# Current generation: 4960
# Best solution so far: 399, Goal: 400
#
# Current generation: 4970
# Best solution so far: 399, Goal: 400
#
# Current generation: 4980
# Best solution so far: 399, Goal: 400
#
# Current generation: 4990
# Best solution so far: 399, Goal: 400
#
# Current generation: 5000
# Best solution so far: 399, Goal: 400
#
# Current generation: 5010
# Best solution so far: 399, Goal: 400
#
# Current generation: 5020
# Best solution so far: 399, Goal: 400
#
# Current generation: 5030
# Best solution so far: 399, Goal: 400
#
# Current generation: 5040
# Best solution so far: 399, Goal: 400
#
# Current generation: 5050
# Best solution so far: 399, Goal: 400
#
# Current generation: 5060
# Best solution so far: 399, Goal: 400
#
# Current generation: 5070
# Best solution so far: 399, Goal: 400
#
# Current generation: 5080
# Best solution so far: 399, Goal: 400
#
# Current generation: 5090
# Best solution so far: 399, Goal: 400
#
# Current generation: 5100
# Best solution so far: 399, Goal: 400
#
# Current generation: 5110
# Best solution so far: 399, Goal: 400
#
# Current generation: 5120
# Best solution so far: 399, Goal: 400
#
# Current generation: 5130
# Best solution so far: 399, Goal: 400
#
# Current generation: 5140
# Best solution so far: 399, Goal: 400
#
# Current generation: 5150
# Best solution so far: 399, Goal: 400
#
# Current generation: 5160
# Best solution so far: 399, Goal: 400
#
# Current generation: 5170
# Best solution so far: 399, Goal: 400
#
# Current generation: 5180
# Best solution so far: 399, Goal: 400
#
# Current generation: 5190
# Best solution so far: 399, Goal: 400
#
# Current generation: 5200
# Best solution so far: 399, Goal: 400
#
# Current generation: 5210
# Best solution so far: 399, Goal: 400
#
# Current generation: 5220
# Best solution so far: 399, Goal: 400
#
# Current generation: 5230
# Best solution so far: 399, Goal: 400
#
# Current generation: 5240
# Best solution so far: 399, Goal: 400
#
# Current generation: 5250
# Best solution so far: 399, Goal: 400
#
# Current generation: 5260
# Best solution so far: 399, Goal: 400
#
# Current generation: 5270
# Best solution so far: 399, Goal: 400
#
# Current generation: 5280
# Best solution so far: 399, Goal: 400
#
# Current generation: 5290
# Best solution so far: 399, Goal: 400
#
# Current generation: 5300
# Best solution so far: 399, Goal: 400
#
# Current generation: 5310
# Best solution so far: 399, Goal: 400
#
# Current generation: 5320
# Best solution so far: 399, Goal: 400
#
# Current generation: 5330
# Best solution so far: 399, Goal: 400
#
# Current generation: 5340
# Best solution so far: 399, Goal: 400
#
# Current generation: 5350
# Best solution so far: 399, Goal: 400
#
# Current generation: 5360
# Best solution so far: 399, Goal: 400
#
# Current generation: 5370
# Best solution so far: 399, Goal: 400
#
# Current generation: 5380
# Best solution so far: 399, Goal: 400
#
# Current generation: 5390
# Best solution so far: 399, Goal: 400
#
# Current generation: 5400
# Best solution so far: 399, Goal: 400
#
# Current generation: 5410
# Best solution so far: 399, Goal: 400
#
# Current generation: 5420
# Best solution so far: 399, Goal: 400
#
# Current generation: 5430
# Best solution so far: 399, Goal: 400
#
# Current generation: 5440
# Best solution so far: 399, Goal: 400
#
# Current generation: 5450
# Best solution so far: 399, Goal: 400
#
# Current generation: 5460
# Best solution so far: 399, Goal: 400
#
# Current generation: 5470
# Best solution so far: 399, Goal: 400
#
# Current generation: 5480
# Best solution so far: 399, Goal: 400
#
# Current generation: 5490
# Best solution so far: 399, Goal: 400
#
# Current generation: 5500
# Best solution so far: 399, Goal: 400
#
# Current generation: 5510
# Best solution so far: 399, Goal: 400
#
# Current generation: 5520
# Best solution so far: 399, Goal: 400
#
# Current generation: 5530
# Best solution so far: 399, Goal: 400
#
# Current generation: 5540
# Best solution so far: 399, Goal: 400
#
# Current generation: 5550
# Best solution so far: 399, Goal: 400
#
# Current generation: 5560
# Best solution so far: 399, Goal: 400
#
# Current generation: 5570
# Best solution so far: 399, Goal: 400
#
# Current generation: 5580
# Best solution so far: 399, Goal: 400
#
# Current generation: 5590
# Best solution so far: 399, Goal: 400
#
# Current generation: 5600
# Best solution so far: 399, Goal: 400
#
# Current generation: 5610
# Best solution so far: 399, Goal: 400
#
# Current generation: 5620
# Best solution so far: 399, Goal: 400
#
# Current generation: 5630
# Best solution so far: 399, Goal: 400
#
# Current generation: 5640
# Best solution so far: 399, Goal: 400
#
# Current generation: 5650
# Best solution so far: 399, Goal: 400
#
# Current generation: 5660
# Best solution so far: 399, Goal: 400
#
# Current generation: 5670
# Best solution so far: 399, Goal: 400
#
# Current generation: 5680
# Best solution so far: 399, Goal: 400
#
# Current generation: 5690
# Best solution so far: 399, Goal: 400
#
# Current generation: 5700
# Best solution so far: 399, Goal: 400
#
# Current generation: 5710
# Best solution so far: 399, Goal: 400
#
# Current generation: 5720
# Best solution so far: 399, Goal: 400
#
# Current generation: 5730
# Best solution so far: 399, Goal: 400
#
# Current generation: 5740
# Best solution so far: 399, Goal: 400
#
# Current generation: 5750
# Best solution so far: 399, Goal: 400
#
# Current generation: 5760
# Best solution so far: 399, Goal: 400
#
# Current generation: 5770
# Best solution so far: 399, Goal: 400
#
# Current generation: 5780
# Best solution so far: 399, Goal: 400
#
# Current generation: 5790
# Best solution so far: 399, Goal: 400
#
# Current generation: 5800
# Best solution so far: 399, Goal: 400
#
# Current generation: 5810
# Best solution so far: 399, Goal: 400
#
# Current generation: 5820
# Best solution so far: 399, Goal: 400
#
# Current generation: 5830
# Best solution so far: 399, Goal: 400
#
# Current generation: 5840
# Best solution so far: 399, Goal: 400
#
# Current generation: 5850
# Best solution so far: 399, Goal: 400
#
# Current generation: 5860
# Best solution so far: 399, Goal: 400
#
# Current generation: 5870
# Best solution so far: 399, Goal: 400
#
# Current generation: 5880
# Best solution so far: 399, Goal: 400
#
# Current generation: 5890
# Best solution so far: 399, Goal: 400
#
# Current generation: 5900
# Best solution so far: 399, Goal: 400
#
# Current generation: 5910
# Best solution so far: 399, Goal: 400
#
# Current generation: 5920
# Best solution so far: 399, Goal: 400
#
# Current generation: 5930
# Best solution so far: 399, Goal: 400
#
# Current generation: 5940
# Best solution so far: 399, Goal: 400
#
# Current generation: 5950
# Best solution so far: 399, Goal: 400
#
# Current generation: 5960
# Best solution so far: 399, Goal: 400
#
# Current generation: 5970
# Best solution so far: 399, Goal: 400
#
# Current generation: 5980
# Best solution so far: 399, Goal: 400
#
# Current generation: 5990
# Best solution so far: 399, Goal: 400
#
# Current generation: 6000
# Best solution so far: 399, Goal: 400
#
# Current generation: 6010
# Best solution so far: 399, Goal: 400
#
# Current generation: 6020
# Best solution so far: 399, Goal: 400
#
# Current generation: 6030
# Best solution so far: 399, Goal: 400
#
# Current generation: 6040
# Best solution so far: 399, Goal: 400
#
# Current generation: 6050
# Best solution so far: 399, Goal: 400
#
# Current generation: 6060
# Best solution so far: 399, Goal: 400
#
# Current generation: 6070
# Best solution so far: 399, Goal: 400
#
# Current generation: 6080
# Best solution so far: 399, Goal: 400
#
# Current generation: 6090
# Best solution so far: 399, Goal: 400
#
# Current generation: 6100
# Best solution so far: 399, Goal: 400
#
# Current generation: 6110
# Best solution so far: 399, Goal: 400
#
# Current generation: 6120
# Best solution so far: 399, Goal: 400
#
# Current generation: 6130
# Best solution so far: 399, Goal: 400
#
# Current generation: 6140
# Best solution so far: 399, Goal: 400
#
# Current generation: 6150
# Best solution so far: 399, Goal: 400
#
# Current generation: 6160
# Best solution so far: 399, Goal: 400
#
# Current generation: 6170
# Best solution so far: 399, Goal: 400
#
# Current generation: 6180
# Best solution so far: 399, Goal: 400
#
# Current generation: 6190
# Best solution so far: 399, Goal: 400
#
# Current generation: 6200
# Best solution so far: 399, Goal: 400
#
# Current generation: 6210
# Best solution so far: 399, Goal: 400
#
# Current generation: 6220
# Best solution so far: 399, Goal: 400
#
# Current generation: 6230
# Best solution so far: 399, Goal: 400
#
# Current generation: 6240
# Best solution so far: 399, Goal: 400
#
# Current generation: 6250
# Best solution so far: 399, Goal: 400
#
# Current generation: 6260
# Best solution so far: 399, Goal: 400
#
# Current generation: 6270
# Best solution so far: 399, Goal: 400
#
# Current generation: 6280
# Best solution so far: 399, Goal: 400
#
# Current generation: 6290
# Best solution so far: 399, Goal: 400
#
# Current generation: 6300
# Best solution so far: 399, Goal: 400
#
# Current generation: 6310
# Best solution so far: 399, Goal: 400
#
# Current generation: 6320
# Best solution so far: 399, Goal: 400
#
# Current generation: 6330
# Best solution so far: 399, Goal: 400
#
# Current generation: 6340
# Best solution so far: 399, Goal: 400
#
# Current generation: 6350
# Best solution so far: 399, Goal: 400
#
# Current generation: 6360
# Best solution so far: 399, Goal: 400
#
# Current generation: 6370
# Best solution so far: 399, Goal: 400
#
# Current generation: 6380
# Best solution so far: 399, Goal: 400
#
# Current generation: 6390
# Best solution so far: 399, Goal: 400
#
# Current generation: 6400
# Best solution so far: 399, Goal: 400
#
# Current generation: 6410
# Best solution so far: 399, Goal: 400
#
# Current generation: 6420
# Best solution so far: 399, Goal: 400
#
# Current generation: 6430
# Best solution so far: 399, Goal: 400
#
# Current generation: 6440
# Best solution so far: 399, Goal: 400
#
# Current generation: 6450
# Best solution so far: 399, Goal: 400
#
# Current generation: 6460
# Best solution so far: 399, Goal: 400
#
# Current generation: 6470
# Best solution so far: 399, Goal: 400
#
# Current generation: 6480
# Best solution so far: 399, Goal: 400
#
# Current generation: 6490
# Best solution so far: 399, Goal: 400
#
# Current generation: 6500
# Best solution so far: 399, Goal: 400
#
# Current generation: 6510
# Best solution so far: 399, Goal: 400
#
# Current generation: 6520
# Best solution so far: 399, Goal: 400
#
# Current generation: 6530
# Best solution so far: 399, Goal: 400
#
# Current generation: 6540
# Best solution so far: 399, Goal: 400
#
# Current generation: 6550
# Best solution so far: 399, Goal: 400
#
# Current generation: 6560
# Best solution so far: 399, Goal: 400
#
# Current generation: 6570
# Best solution so far: 399, Goal: 400
#
# Current generation: 6580
# Best solution so far: 399, Goal: 400
#
# Current generation: 6590
# Best solution so far: 399, Goal: 400
#
# Current generation: 6600
# Best solution so far: 399, Goal: 400
#
# Current generation: 6610
# Best solution so far: 399, Goal: 400
#
# Current generation: 6620
# Best solution so far: 399, Goal: 400
#
# Current generation: 6630
# Best solution so far: 399, Goal: 400
#
# Current generation: 6640
# Best solution so far: 399, Goal: 400
#
# Current generation: 6650
# Best solution so far: 399, Goal: 400
#
# Current generation: 6660
# Best solution so far: 399, Goal: 400
#
# Current generation: 6670
# Best solution so far: 399, Goal: 400
#
# Current generation: 6680
# Best solution so far: 399, Goal: 400
#
# Current generation: 6690
# Best solution so far: 399, Goal: 400
#
# Current generation: 6700
# Best solution so far: 399, Goal: 400
#
# Current generation: 6710
# Best solution so far: 399, Goal: 400
#
# Current generation: 6720
# Best solution so far: 399, Goal: 400
#
# Current generation: 6730
# Best solution so far: 399, Goal: 400
#
# Current generation: 6740
# Best solution so far: 399, Goal: 400
#
# Current generation: 6750
# Best solution so far: 399, Goal: 400
#
# Current generation: 6760
# Best solution so far: 399, Goal: 400
#
# Current generation: 6770
# Best solution so far: 399, Goal: 400
#
# Current generation: 6780
# Best solution so far: 399, Goal: 400
#
# Current generation: 6790
# Best solution so far: 399, Goal: 400
#
# Current generation: 6800
# Best solution so far: 399, Goal: 400
#
# Current generation: 6810
# Best solution so far: 399, Goal: 400
#
# Current generation: 6820
# Best solution so far: 399, Goal: 400
#
# Current generation: 6830
# Best solution so far: 399, Goal: 400
#
# Current generation: 6840
# Best solution so far: 399, Goal: 400
#
# Current generation: 6850
# Best solution so far: 399, Goal: 400
#
# Current generation: 6860
# Best solution so far: 399, Goal: 400
#
# Current generation: 6870
# Best solution so far: 399, Goal: 400
#
# Current generation: 6880
# Best solution so far: 399, Goal: 400
#
# Current generation: 6890
# Best solution so far: 399, Goal: 400
#
# Current generation: 6900
# Best solution so far: 399, Goal: 400
#
# Current generation: 6910
# Best solution so far: 399, Goal: 400
#
# Current generation: 6920
# Best solution so far: 399, Goal: 400
#
# Current generation: 6930
# Best solution so far: 399, Goal: 400
#
# Current generation: 6940
# Best solution so far: 399, Goal: 400
#
# Current generation: 6950
# Best solution so far: 399, Goal: 400
#
# Current generation: 6960
# Best solution so far: 399, Goal: 400
#
# Current generation: 6970
# Best solution so far: 399, Goal: 400
#
# Current generation: 6980
# Best solution so far: 399, Goal: 400
#
# Current generation: 6990
# Best solution so far: 399, Goal: 400
#
# Current generation: 7000
# Best solution so far: 399, Goal: 400
#
# Current generation: 7010
# Best solution so far: 399, Goal: 400
#
# Current generation: 7020
# Best solution so far: 399, Goal: 400
#
# Current generation: 7030
# Best solution so far: 399, Goal: 400
#
# Current generation: 7040
# Best solution so far: 399, Goal: 400
#
# Current generation: 7050
# Best solution so far: 399, Goal: 400
#
# Current generation: 7060
# Best solution so far: 399, Goal: 400
#
# Current generation: 7070
# Best solution so far: 399, Goal: 400
#
# Current generation: 7080
# Best solution so far: 399, Goal: 400
#
# Current generation: 7090
# Best solution so far: 399, Goal: 400
#
# Current generation: 7100
# Best solution so far: 399, Goal: 400
#
# Current generation: 7110
# Best solution so far: 399, Goal: 400
#
# Current generation: 7120
# Best solution so far: 399, Goal: 400
#
# Current generation: 7130
# Best solution so far: 399, Goal: 400
#
# Current generation: 7140
# Best solution so far: 399, Goal: 400
#
# Current generation: 7150
# Best solution so far: 399, Goal: 400
#
# Current generation: 7160
# Best solution so far: 399, Goal: 400
#
# Current generation: 7170
# Best solution so far: 399, Goal: 400
#
# Current generation: 7180
# Best solution so far: 399, Goal: 400
#
# Current generation: 7190
# Best solution so far: 399, Goal: 400
#
# Current generation: 7200
# Best solution so far: 399, Goal: 400
#
# Current generation: 7210
# Best solution so far: 399, Goal: 400
#
# Current generation: 7220
# Best solution so far: 399, Goal: 400
#
# Current generation: 7230
# Best solution so far: 399, Goal: 400
#
# Current generation: 7240
# Best solution so far: 399, Goal: 400
#
# Current generation: 7250
# Best solution so far: 399, Goal: 400
#
# Current generation: 7260
# Best solution so far: 399, Goal: 400
#
# Current generation: 7270
# Best solution so far: 399, Goal: 400
#
# Current generation: 7280
# Best solution so far: 399, Goal: 400
#
# Current generation: 7290
# Best solution so far: 399, Goal: 400
#
# Current generation: 7300
# Best solution so far: 399, Goal: 400
#
# Current generation: 7310
# Best solution so far: 399, Goal: 400
#
# Current generation: 7320
# Best solution so far: 399, Goal: 400
#
# Current generation: 7330
# Best solution so far: 399, Goal: 400
#
# Current generation: 7340
# Best solution so far: 399, Goal: 400
#
# Current generation: 7350
# Best solution so far: 399, Goal: 400
#
# Current generation: 7360
# Best solution so far: 399, Goal: 400
#
# Current generation: 7370
# Best solution so far: 399, Goal: 400
#
# Current generation: 7380
# Best solution so far: 399, Goal: 400
#
# Current generation: 7390
# Best solution so far: 399, Goal: 400
#
# Current generation: 7400
# Best solution so far: 399, Goal: 400
#
# Current generation: 7410
# Best solution so far: 399, Goal: 400
#
# Current generation: 7420
# Best solution so far: 399, Goal: 400
#
# Current generation: 7430
# Best solution so far: 399, Goal: 400
#
# Current generation: 7440
# Best solution so far: 399, Goal: 400
#
# Current generation: 7450
# Best solution so far: 399, Goal: 400
#
# Current generation: 7460
# Best solution so far: 399, Goal: 400
#
# Current generation: 7470
# Best solution so far: 399, Goal: 400
#
# Current generation: 7480
# Best solution so far: 399, Goal: 400
#
# Current generation: 7490
# Best solution so far: 399, Goal: 400
#
# Current generation: 7500
# Best solution so far: 399, Goal: 400
#
# Current generation: 7510
# Best solution so far: 399, Goal: 400
#
# Current generation: 7520
# Best solution so far: 399, Goal: 400
#
# Current generation: 7530
# Best solution so far: 399, Goal: 400
#
# Current generation: 7540
# Best solution so far: 399, Goal: 400
#
# Current generation: 7550
# Best solution so far: 399, Goal: 400
#
# Current generation: 7560
# Best solution so far: 399, Goal: 400
#
# Current generation: 7570
# Best solution so far: 399, Goal: 400
#
# Current generation: 7580
# Best solution so far: 399, Goal: 400
#
# Current generation: 7590
# Best solution so far: 399, Goal: 400
#
# Current generation: 7600
# Best solution so far: 399, Goal: 400
#
# Current generation: 7610
# Best solution so far: 399, Goal: 400
#
# Current generation: 7620
# Best solution so far: 399, Goal: 400
#
# Current generation: 7630
# Best solution so far: 399, Goal: 400
#
# Current generation: 7640
# Best solution so far: 399, Goal: 400
#
# Current generation: 7650
# Best solution so far: 399, Goal: 400
#
# Current generation: 7660
# Best solution so far: 399, Goal: 400
#
# Current generation: 7670
# Best solution so far: 399, Goal: 400
#
# Current generation: 7680
# Best solution so far: 399, Goal: 400
#
# Current generation: 7690
# Best solution so far: 399, Goal: 400
#
# Current generation: 7700
# Best solution so far: 399, Goal: 400
#
# Current generation: 7710
# Best solution so far: 399, Goal: 400
#
# Current generation: 7720
# Best solution so far: 399, Goal: 400
#
# Current generation: 7730
# Best solution so far: 399, Goal: 400
#
# Current generation: 7740
# Best solution so far: 399, Goal: 400
#
# Current generation: 7750
# Best solution so far: 399, Goal: 400
#
# Current generation: 7760
# Best solution so far: 399, Goal: 400
#
# Current generation: 7770
# Best solution so far: 399, Goal: 400
#
# Current generation: 7780
# Best solution so far: 399, Goal: 400
#
# Current generation: 7790
# Best solution so far: 399, Goal: 400
#
# Current generation: 7800
# Best solution so far: 399, Goal: 400
#
# Current generation: 7810
# Best solution so far: 399, Goal: 400
#
# Current generation: 7820
# Best solution so far: 399, Goal: 400
#
# Current generation: 7830
# Best solution so far: 399, Goal: 400
#
# Current generation: 7840
# Best solution so far: 399, Goal: 400
#
# Current generation: 7850
# Best solution so far: 399, Goal: 400
#
# Current generation: 7860
# Best solution so far: 399, Goal: 400
#
# Current generation: 7870
# Best solution so far: 399, Goal: 400
#
# Current generation: 7880
# Best solution so far: 399, Goal: 400
#
# Current generation: 7890
# Best solution so far: 399, Goal: 400
#
# Current generation: 7900
# Best solution so far: 399, Goal: 400
#
# Current generation: 7910
# Best solution so far: 399, Goal: 400
#
# Current generation: 7920
# Best solution so far: 399, Goal: 400
#
# Current generation: 7930
# Best solution so far: 399, Goal: 400
#
# Current generation: 7940
# Best solution so far: 399, Goal: 400
#
# Current generation: 7950
# Best solution so far: 399, Goal: 400
#
# Current generation: 7960
# Best solution so far: 399, Goal: 400
#
# Current generation: 7970
# Best solution so far: 399, Goal: 400
#
# Current generation: 7980
# Best solution so far: 399, Goal: 400
#
# Current generation: 7990
# Best solution so far: 399, Goal: 400
#
# Current generation: 8000
# Best solution so far: 399, Goal: 400
#
# Current generation: 8010
# Best solution so far: 399, Goal: 400
#
# Current generation: 8020
# Best solution so far: 399, Goal: 400
#
# Current generation: 8030
# Best solution so far: 399, Goal: 400
#
# Current generation: 8040
# Best solution so far: 399, Goal: 400
#
# Current generation: 8050
# Best solution so far: 399, Goal: 400
#
# Current generation: 8060
# Best solution so far: 399, Goal: 400
#
# Current generation: 8070
# Best solution so far: 399, Goal: 400
#
# Current generation: 8080
# Best solution so far: 399, Goal: 400
#
# Current generation: 8090
# Best solution so far: 399, Goal: 400
#
# Current generation: 8100
# Best solution so far: 399, Goal: 400
#
# Current generation: 8110
# Best solution so far: 399, Goal: 400
#
# Current generation: 8120
# Best solution so far: 399, Goal: 400
#
# Current generation: 8130
# Best solution so far: 399, Goal: 400
#
# Current generation: 8140
# Best solution so far: 399, Goal: 400
#
# Current generation: 8150
# Best solution so far: 399, Goal: 400
#
# Current generation: 8160
# Best solution so far: 399, Goal: 400
#
# Current generation: 8170
# Best solution so far: 399, Goal: 400
#
# Current generation: 8180
# Best solution so far: 399, Goal: 400
#
# Current generation: 8190
# Best solution so far: 399, Goal: 400
#
# Current generation: 8200
# Best solution so far: 399, Goal: 400
#
# Current generation: 8210
# Best solution so far: 399, Goal: 400
#
# Current generation: 8220
# Best solution so far: 399, Goal: 400
#
# Current generation: 8230
# Best solution so far: 399, Goal: 400
#
# Current generation: 8240
# Best solution so far: 399, Goal: 400
#
# Current generation: 8250
# Best solution so far: 399, Goal: 400
#
# Current generation: 8260
# Best solution so far: 399, Goal: 400
#
# Current generation: 8270
# Best solution so far: 399, Goal: 400
#
# Current generation: 8280
# Best solution so far: 399, Goal: 400
#
# Current generation: 8290
# Best solution so far: 399, Goal: 400
#
# Current generation: 8300
# Best solution so far: 399, Goal: 400
#
# Current generation: 8310
# Best solution so far: 399, Goal: 400
#
# Current generation: 8320
# Best solution so far: 399, Goal: 400
#
# Current generation: 8330
# Best solution so far: 399, Goal: 400
#
# Current generation: 8340
# Best solution so far: 399, Goal: 400
#
# Current generation: 8350
# Best solution so far: 399, Goal: 400
#
# Current generation: 8360
# Best solution so far: 399, Goal: 400
#
# Current generation: 8370
# Best solution so far: 399, Goal: 400
#
# Current generation: 8380
# Best solution so far: 399, Goal: 400
#
# Current generation: 8390
# Best solution so far: 399, Goal: 400
#
# Current generation: 8400
# Best solution so far: 399, Goal: 400
#
# Current generation: 8410
# Best solution so far: 399, Goal: 400
#
# Current generation: 8420
# Best solution so far: 399, Goal: 400
#
# Current generation: 8430
# Best solution so far: 399, Goal: 400
#
# Current generation: 8440
# Best solution so far: 399, Goal: 400
#
# Current generation: 8450
# Best solution so far: 399, Goal: 400
#
# Current generation: 8460
# Best solution so far: 399, Goal: 400
#
# Current generation: 8470
# Best solution so far: 399, Goal: 400
#
# Current generation: 8480
# Best solution so far: 399, Goal: 400
#
# Current generation: 8490
# Best solution so far: 399, Goal: 400
#
# Current generation: 8500
# Best solution so far: 399, Goal: 400
#
# Current generation: 8510
# Best solution so far: 399, Goal: 400
#
# Current generation: 8520
# Best solution so far: 399, Goal: 400
#
# Current generation: 8530
# Best solution so far: 399, Goal: 400
#
# Current generation: 8540
# Best solution so far: 399, Goal: 400
#
# Current generation: 8550
# Best solution so far: 399, Goal: 400
#
# Current generation: 8560
# Best solution so far: 399, Goal: 400
#
# Current generation: 8570
# Best solution so far: 399, Goal: 400
#
# Current generation: 8580
# Best solution so far: 399, Goal: 400
#
# Current generation: 8590
# Best solution so far: 399, Goal: 400
#
# Current generation: 8600
# Best solution so far: 399, Goal: 400
#
# Current generation: 8610
# Best solution so far: 399, Goal: 400
#
# Current generation: 8620
# Best solution so far: 399, Goal: 400
#
# Current generation: 8630
# Best solution so far: 399, Goal: 400
#
# Current generation: 8640
# Best solution so far: 399, Goal: 400
#
# Current generation: 8650
# Best solution so far: 399, Goal: 400
#
# Current generation: 8660
# Best solution so far: 399, Goal: 400
#
# Current generation: 8670
# Best solution so far: 399, Goal: 400
#
# Current generation: 8680
# Best solution so far: 399, Goal: 400
#
# Current generation: 8690
# Best solution so far: 399, Goal: 400
#
# Current generation: 8700
# Best solution so far: 399, Goal: 400
#
# Current generation: 8710
# Best solution so far: 399, Goal: 400
#
# Current generation: 8720
# Best solution so far: 399, Goal: 400
#
# Current generation: 8730
# Best solution so far: 399, Goal: 400
#
# Current generation: 8740
# Best solution so far: 399, Goal: 400
#
# Current generation: 8750
# Best solution so far: 399, Goal: 400
#
# Current generation: 8760
# Best solution so far: 399, Goal: 400
#
# Current generation: 8770
# Best solution so far: 399, Goal: 400
#
# Current generation: 8780
# Best solution so far: 399, Goal: 400
#
# Current generation: 8790
# Best solution so far: 399, Goal: 400
#
# Current generation: 8800
# Best solution so far: 399, Goal: 400
#
# Current generation: 8810
# Best solution so far: 399, Goal: 400
#
# Current generation: 8820
# Best solution so far: 399, Goal: 400
#
# Current generation: 8830
# Best solution so far: 399, Goal: 400
#
# Current generation: 8840
# Best solution so far: 399, Goal: 400
#
# Current generation: 8850
# Best solution so far: 399, Goal: 400
#
# Current generation: 8860
# Best solution so far: 399, Goal: 400
#
# Current generation: 8870
# Best solution so far: 399, Goal: 400
#
# Current generation: 8880
# Best solution so far: 399, Goal: 400
#
# Current generation: 8890
# Best solution so far: 399, Goal: 400
#
# Current generation: 8900
# Best solution so far: 399, Goal: 400
#
# Current generation: 8910
# Best solution so far: 399, Goal: 400
#
# Current generation: 8920
# Best solution so far: 399, Goal: 400
#
# Current generation: 8930
# Best solution so far: 399, Goal: 400
#
# Current generation: 8940
# Best solution so far: 399, Goal: 400
#
# Current generation: 8950
# Best solution so far: 399, Goal: 400
#
# Current generation: 8960
# Best solution so far: 399, Goal: 400
#
# Current generation: 8970
# Best solution so far: 399, Goal: 400
#
# Current generation: 8980
# Best solution so far: 399, Goal: 400
#
# Current generation: 8990
# Best solution so far: 399, Goal: 400
#
# Current generation: 9000
# Best solution so far: 399, Goal: 400
#
# Current generation: 9010
# Best solution so far: 399, Goal: 400
#
# Current generation: 9020
# Best solution so far: 399, Goal: 400
#
# Current generation: 9030
# Best solution so far: 399, Goal: 400
#
# Current generation: 9040
# Best solution so far: 399, Goal: 400
#
# Current generation: 9050
# Best solution so far: 399, Goal: 400
#
# Current generation: 9060
# Best solution so far: 399, Goal: 400
#
# Current generation: 9070
# Best solution so far: 399, Goal: 400
#
# Current generation: 9080
# Best solution so far: 399, Goal: 400
#
# Current generation: 9090
# Best solution so far: 399, Goal: 400
#
# Current generation: 9100
# Best solution so far: 399, Goal: 400
#
# Current generation: 9110
# Best solution so far: 399, Goal: 400
#
# Current generation: 9120
# Best solution so far: 399, Goal: 400
#
# Current generation: 9130
# Best solution so far: 399, Goal: 400
#
# Current generation: 9140
# Best solution so far: 399, Goal: 400
#
# Current generation: 9150
# Best solution so far: 399, Goal: 400
#
# Current generation: 9160
# Best solution so far: 399, Goal: 400
#
# Current generation: 9170
# Best solution so far: 399, Goal: 400
#
# Current generation: 9180
# Best solution so far: 399, Goal: 400
#
# Current generation: 9190
# Best solution so far: 399, Goal: 400
#
# Current generation: 9200
# Best solution so far: 399, Goal: 400
#
# Current generation: 9210
# Best solution so far: 399, Goal: 400
#
# Current generation: 9220
# Best solution so far: 399, Goal: 400
#
# Current generation: 9230
# Best solution so far: 399, Goal: 400
#
# Current generation: 9240
# Best solution so far: 399, Goal: 400
#
# Current generation: 9250
# Best solution so far: 399, Goal: 400
#
# Current generation: 9260
# Best solution so far: 399, Goal: 400
#
# Current generation: 9270
# Best solution so far: 399, Goal: 400
#
# Current generation: 9280
# Best solution so far: 399, Goal: 400
#
# Current generation: 9290
# Best solution so far: 399, Goal: 400
#
# Current generation: 9300
# Best solution so far: 399, Goal: 400
#
# Current generation: 9310
# Best solution so far: 399, Goal: 400
#
# Current generation: 9320
# Best solution so far: 399, Goal: 400
#
# Current generation: 9330
# Best solution so far: 399, Goal: 400
#
# Current generation: 9340
# Best solution so far: 399, Goal: 400
#
# Current generation: 9350
# Best solution so far: 399, Goal: 400
#
# Current generation: 9360
# Best solution so far: 399, Goal: 400
#
# Current generation: 9370
# Best solution so far: 399, Goal: 400
#
# Current generation: 9380
# Best solution so far: 399, Goal: 400
#
# Current generation: 9390
# Best solution so far: 399, Goal: 400
#
# Current generation: 9400
# Best solution so far: 399, Goal: 400
#
# Current generation: 9410
# Best solution so far: 399, Goal: 400
#
# Current generation: 9420
# Best solution so far: 399, Goal: 400
#
# Current generation: 9430
# Best solution so far: 399, Goal: 400
#
# Current generation: 9440
# Best solution so far: 399, Goal: 400
#
# Current generation: 9450
# Best solution so far: 399, Goal: 400
#
# Current generation: 9460
# Best solution so far: 399, Goal: 400
#
# Current generation: 9470
# Best solution so far: 399, Goal: 400
#
# Current generation: 9480
# Best solution so far: 399, Goal: 400
#
# Current generation: 9490
# Best solution so far: 399, Goal: 400
#
# Current generation: 9500
# Best solution so far: 399, Goal: 400
#
# Current generation: 9510
# Best solution so far: 399, Goal: 400
#
# Current generation: 9520
# Best solution so far: 399, Goal: 400
#
# Current generation: 9530
# Best solution so far: 399, Goal: 400
#
# Current generation: 9540
# Best solution so far: 399, Goal: 400
#
# Current generation: 9550
# Best solution so far: 399, Goal: 400
#
# Current generation: 9560
# Best solution so far: 399, Goal: 400
#
# Current generation: 9570
# Best solution so far: 399, Goal: 400
#
# Current generation: 9580
# Best solution so far: 399, Goal: 400
#
# Current generation: 9590
# Best solution so far: 399, Goal: 400
#
# Current generation: 9600
# Best solution so far: 399, Goal: 400
#
# Current generation: 9610
# Best solution so far: 399, Goal: 400
#
# Current generation: 9620
# Best solution so far: 399, Goal: 400
#
# Current generation: 9630
# Best solution so far: 399, Goal: 400
#
# Current generation: 9640
# Best solution so far: 399, Goal: 400
#
# Current generation: 9650
# Best solution so far: 399, Goal: 400
#
# Current generation: 9660
# Best solution so far: 399, Goal: 400
#
# Current generation: 9670
# Best solution so far: 399, Goal: 400
#
# Current generation: 9680
# Best solution so far: 399, Goal: 400
#
# Current generation: 9690
# Best solution so far: 399, Goal: 400
#
# Current generation: 9700
# Best solution so far: 399, Goal: 400
#
# Current generation: 9710
# Best solution so far: 399, Goal: 400
#
# Current generation: 9720
# Best solution so far: 399, Goal: 400
#
# Current generation: 9730
# Best solution so far: 399, Goal: 400
#
# Current generation: 9740
# Best solution so far: 399, Goal: 400
#
# Current generation: 9750
# Best solution so far: 399, Goal: 400
#
# Current generation: 9760
# Best solution so far: 399, Goal: 400
#
# Current generation: 9770
# Best solution so far: 399, Goal: 400
#
# Current generation: 9780
# Best solution so far: 399, Goal: 400
#
# Current generation: 9790
# Best solution so far: 399, Goal: 400
#
# Current generation: 9800
# Best solution so far: 399, Goal: 400
#
# Current generation: 9810
# Best solution so far: 399, Goal: 400
#
# Current generation: 9820
# Best solution so far: 399, Goal: 400
#
# Current generation: 9830
# Best solution so far: 399, Goal: 400
#
# Current generation: 9840
# Best solution so far: 399, Goal: 400
#
# Current generation: 9850
# Best solution so far: 399, Goal: 400
#
# Current generation: 9860
# Best solution so far: 399, Goal: 400
#
# Current generation: 9870
# Best solution so far: 399, Goal: 400
#
# Current generation: 9880
# Best solution so far: 399, Goal: 400
#
# Current generation: 9890
# Best solution so far: 399, Goal: 400
#
# Current generation: 9900
# Best solution so far: 399, Goal: 400
#
# Current generation: 9910
# Best solution so far: 399, Goal: 400
#
# Current generation: 9920
# Best solution so far: 399, Goal: 400
#
# Current generation: 9930
# Best solution so far: 399, Goal: 400
#
# Current generation: 9940
# Best solution so far: 399, Goal: 400
#
# Current generation: 9950
# Best solution so far: 399, Goal: 400
#
# Current generation: 9960
# Best solution so far: 399, Goal: 400
#
# Current generation: 9970
# Best solution so far: 399, Goal: 400
#
# Current generation: 9980
# Best solution so far: 399, Goal: 400
#
# Current generation: 9990
# Best solution so far: 399, Goal: 400
#
# Current generation: 10000
# Best solution so far: 399, Goal: 400
#
# Current generation: 10010
# Best solution so far: 399, Goal: 400
#
# Current generation: 10020
# Best solution so far: 399, Goal: 400
#
# Current generation: 10030
# Best solution so far: 399, Goal: 400
#
# Current generation: 10040
# Best solution so far: 399, Goal: 400
#
# Current generation: 10050
# Best solution so far: 399, Goal: 400
#
# Current generation: 10060
# Best solution so far: 399, Goal: 400
#
# Current generation: 10070
# Best solution so far: 399, Goal: 400
#
# Current generation: 10080
# Best solution so far: 399, Goal: 400
#
# Current generation: 10090
# Best solution so far: 399, Goal: 400
#
# ...
#
# Current generation: 17550
# Best solution so far: 399, Goal: 400
#
# Current generation: 17560
# Best solution so far: 399, Goal: 400
#
# Current generation: 17570
# Best solution so far: 399, Goal: 400
#
# Current generation: 17580
# Best solution so far: 399, Goal: 400
#
# Current generation: 17590
# Best solution so far: 399, Goal: 400
#
# Current generation: 17600
# Best solution so far: 399, Goal: 400
#
# Current generation: 17610
# Best solution so far: 399, Goal: 400
#
# Current generation: 17620
# Best solution so far: 399, Goal: 400
#
# Current generation: 17630
# Best solution so far: 399, Goal: 400
#
# Current generation: 17640
# Best solution so far: 399, Goal: 400
#
# Current generation: 17650
# Best solution so far: 399, Goal: 400
#
# Current generation: 17660
# Best solution so far: 399, Goal: 400
#
# Current generation: 17670
# Best solution so far: 399, Goal: 400
#
# Current generation: 17680
# Best solution so far: 399, Goal: 400
#
# Current generation: 17690
# Best solution so far: 399, Goal: 400
#
# Current generation: 17700
# Best solution so far: 399, Goal: 400
#
# Current generation: 17710
# Best solution so far: 399, Goal: 400
#
# Current generation: 17720
# Best solution so far: 399, Goal: 400
#
# Current generation: 17730
# Best solution so far: 399, Goal: 400
#
# Current generation: 17740
# Best solution so far: 399, Goal: 400
#
# Current generation: 17750
# Best solution so far: 399, Goal: 400
#
# Current generation: 17760
# Best solution so far: 399, Goal: 400
#
# Current generation: 17770
# Best solution so far: 399, Goal: 400
#
# Current generation: 17780
# Best solution so far: 399, Goal: 400
#
# Current generation: 17790
# Best solution so far: 399, Goal: 400
#
# Current generation: 17800
# Best solution so far: 399, Goal: 400
#
# Current generation: 17810
# Best solution so far: 399, Goal: 400
#
# Current generation: 17820
# Best solution so far: 399, Goal: 400
#
# Current generation: 17830
# Best solution so far: 399, Goal: 400
#
# Current generation: 17840
# Best solution so far: 399, Goal: 400
#
# Current generation: 17850
# Best solution so far: 399, Goal: 400
#
# Current generation: 17860
# Best solution so far: 399, Goal: 400
#
# Current generation: 17870
# Best solution so far: 399, Goal: 400
#
# Current generation: 17880
# Best solution so far: 399, Goal: 400
#
# Current generation: 17890
# Best solution so far: 399, Goal: 400
#
# Current generation: 17900
# Best solution so far: 399, Goal: 400
#
# Current generation: 17910
# Best solution so far: 399, Goal: 400
#
# Current generation: 17920
# Best solution so far: 399, Goal: 400
#
# Current generation: 17930
# Best solution so far: 399, Goal: 400
#
# Current generation: 17940
# Best solution so far: 399, Goal: 400
#
# Current generation: 17950
# Best solution so far: 399, Goal: 400
#
# Current generation: 17960
# Best solution so far: 399, Goal: 400
#
# Current generation: 17970
# Best solution so far: 399, Goal: 400
#
# Current generation: 17980
# Best solution so far: 399, Goal: 400
#
# Current generation: 17990
# Best solution so far: 399, Goal: 400
#
# Current generation: 18000
# Best solution so far: 399, Goal: 400
#
# Current generation: 18010
# Best solution so far: 399, Goal: 400
#
# Current generation: 18020
# Best solution so far: 399, Goal: 400
#
# Current generation: 18030
# Best solution so far: 399, Goal: 400
#
# Current generation: 18040
# Best solution so far: 399, Goal: 400
#
# Current generation: 18050
# Best solution so far: 399, Goal: 400
#
# Current generation: 18060
# Best solution so far: 399, Goal: 400
#
# Current generation: 18070
# Best solution so far: 399, Goal: 400
#
# Current generation: 18080
# Best solution so far: 399, Goal: 400
#
# Current generation: 18090
# Best solution so far: 399, Goal: 400
#
# Current generation: 18100
# Best solution so far: 399, Goal: 400
#
# Current generation: 18110
# Best solution so far: 399, Goal: 400
#
# Current generation: 18120
# Best solution so far: 399, Goal: 400
#
# Current generation: 18130
# Best solution so far: 399, Goal: 400
#
# Current generation: 18140
# Best solution so far: 399, Goal: 400
#
# Current generation: 18150
# Best solution so far: 399, Goal: 400
#
# Current generation: 18160
# Best solution so far: 399, Goal: 400
#
# Current generation: 18170
# Best solution so far: 399, Goal: 400
#
# Current generation: 18180
# Best solution so far: 399, Goal: 400
#
# Current generation: 18190
# Best solution so far: 399, Goal: 400
#
# Current generation: 18200
# Best solution so far: 399, Goal: 400
#
# Current generation: 18210
# Best solution so far: 399, Goal: 400
#
# Current generation: 18220
# Best solution so far: 399, Goal: 400
#
# Current generation: 18230
# Best solution so far: 399, Goal: 400
#
# Current generation: 18240
# Best solution so far: 399, Goal: 400
#
# Current generation: 18250
# Best solution so far: 399, Goal: 400
#
# Current generation: 18260
# Best solution so far: 399, Goal: 400
#
# Current generation: 18270
# Best solution so far: 399, Goal: 400
#
# Current generation: 18280
# Best solution so far: 399, Goal: 400
#
# Current generation: 18290
# Best solution so far: 399, Goal: 400
#
# Current generation: 18300
# Best solution so far: 399, Goal: 400
#
# Current generation: 18310
# Best solution so far: 399, Goal: 400
#
# Current generation: 18320
# Best solution so far: 399, Goal: 400
#
# Current generation: 18330
# Best solution so far: 399, Goal: 400
#
# Current generation: 18340
# Best solution so far: 399, Goal: 400
#
# Current generation: 18350
# Best solution so far: 399, Goal: 400
#
# Current generation: 18360
# Best solution so far: 399, Goal: 400
#
# Current generation: 18370
# Best solution so far: 399, Goal: 400
#
# Current generation: 18380
# Best solution so far: 399, Goal: 400
#
# Current generation: 18390
# Best solution so far: 399, Goal: 400
#
# Current generation: 18400
# Best solution so far: 399, Goal: 400
#
# Current generation: 18410
# Best solution so far: 399, Goal: 400
#
# Current generation: 18420
# Best solution so far: 399, Goal: 400
#
# Current generation: 18430
# Best solution so far: 399, Goal: 400
#
# Current generation: 18440
# Best solution so far: 399, Goal: 400
#
# Current generation: 18450
# Best solution so far: 399, Goal: 400
#
# Current generation: 18460
# Best solution so far: 399, Goal: 400
#
# Current generation: 18470
# Best solution so far: 399, Goal: 400
#
# Current generation: 18480
# Best solution so far: 399, Goal: 400
#
# Current generation: 18490
# Best solution so far: 399, Goal: 400
#
# Current generation: 18500
# Best solution so far: 399, Goal: 400
#
# Current generation: 18510
# Best solution so far: 399, Goal: 400
#
# Current generation: 18520
# Best solution so far: 399, Goal: 400
#
# Current generation: 18530
# Best solution so far: 399, Goal: 400
#
# Current generation: 18540
# Best solution so far: 399, Goal: 400
#
# Current generation: 18550
# Best solution so far: 399, Goal: 400
#
# Current generation: 18560
# Best solution so far: 399, Goal: 400
#
# Current generation: 18570
# Best solution so far: 399, Goal: 400
#
# Current generation: 18580
# Best solution so far: 399, Goal: 400
#
# Current generation: 18590
# Best solution so far: 399, Goal: 400
#
# Current generation: 18600
# Best solution so far: 399, Goal: 400
#
# Current generation: 18610
# Best solution so far: 399, Goal: 400
#
# Current generation: 18620
# Best solution so far: 399, Goal: 400
#
# Current generation: 18630
# Best solution so far: 399, Goal: 400
#
# Current generation: 18640
# Best solution so far: 399, Goal: 400
#
# Current generation: 18650
# Best solution so far: 399, Goal: 400
#
# Current generation: 18660
# Best solution so far: 399, Goal: 400
#
# Current generation: 18670
# Best solution so far: 399, Goal: 400
#
# Current generation: 18680
# Best solution so far: 399, Goal: 400
#
# Current generation: 18690
# Best solution so far: 399, Goal: 400
#
# Current generation: 18700
# Best solution so far: 399, Goal: 400
#
# Current generation: 18710
# Best solution so far: 399, Goal: 400
#
# Current generation: 18720
# Best solution so far: 399, Goal: 400
#
# Current generation: 18730
# Best solution so far: 399, Goal: 400
#
# Current generation: 18740
# Best solution so far: 399, Goal: 400
#
# Current generation: 18750
# Best solution so far: 399, Goal: 400
#
# Current generation: 18760
# Best solution so far: 399, Goal: 400
#
# Current generation: 18770
# Best solution so far: 399, Goal: 400
#
# Solution found:
# Value: 400, Goal: 400
#
# Hard Constraints:
# 1: An exam will be scheduled for each course				 ✔
# 2: A student is enrolled in minimum three courses			 ✔
# 3: A student can not give more than one exam at a time			 ✔
# 4: All exams must be held between 9 AM and 5 PM				 ✔
# 5: A teacher can not invigilate two exams at the same time		 ✔
# 6: A teacher can not invigilate two exams in a row			 ✔
# 7: No exam scheduled in the same room at the same time			 ✔
#
# Soft Constraints:
# 1: An exam will be scheduled for each course				 ✔
# 2: A student shall not give more than one exam consecutively		 ✔
# 3: MG courses preferably be held before CS courses			 ✔
# 4: Two hours of break for faculty meeting				 ✔
#
#
# SCHEDULE:
# --------
#
# Week 1
# ------
#
# 		Saturday
# 		---------------------------------------------------------------------------------------------------------------
# 		| AIE332 | Deep Learning                   | 3:00 PM | Room 1: N224 | Mai Ibrahim , Mohamed Abdelaziz   |
# 		---------------------------------------------------------------------------------------------------------------
#
# 		Sunday
# 		---------------------------------------------------------------------------------------------------------------
# 		| AIE425 | Intelligent Recommender Systems | 12:00 AM | Room 1: N147 | Samy Ghoniem , Manar Elshazly      |
# 		---------------------------------------------------------------------------------------------------------------
# 		| AIE231 | Neural Networks                 | 3:00 PM | Room 1: N247 | Mohamed Ghetas , Berhan      |
# 		---------------------------------------------------------------------------------------------------------------
#
# 		Monday
# 		---------------------------------------------------------------------------------------------------------------
# 		| CSE251 | Software Engineering            | 12:00 AM | Room 1: Q100 | Mohamed Abdullah , Mohamed Emam Ismail |
# 		---------------------------------------------------------------------------------------------------------------
# 		| ELE437 | Digital Signal Processing       | 12:00 AM | Room 1: J301 | Gamal Fahmy , Ahmed Heikal        |
# 		---------------------------------------------------------------------------------------------------------------
# 		| AIE213 | Optimization Techniques         | 3:00 PM | Room 1: NG24 | Mohamed Amir , Ahmed Nader        |
# 		---------------------------------------------------------------------------------------------------------------
#
# 		Tuesday
# 		---------------------------------------------------------------------------------------------------------------
# 		| CSE113 | Electric and Electronic Circuits | 12:00 AM | Room 1: N224 | Ahmed Nader , Berhan         |
# 		---------------------------------------------------------------------------------------------------------------
# 		| CSE315 | Discrete Mathematics            | 3:00 PM | Room 1: N224 | Mohamed Abdelaziz , Mahmoud Safwat   |
# 		---------------------------------------------------------------------------------------------------------------
# 		| AIE351 | Robotics Design                 | 3:00 PM | Room 1: NG24 | Safa Elaskary , Mohamed Ghetas      |
# 		---------------------------------------------------------------------------------------------------------------
#
# 		Wednesday
# 		---------------------------------------------------------------------------------------------------------------
# 		| MAT112 | Mathematics II                  | 12:00 AM | Room 1: J300 | Sameh Basha , Gamal Fahmy         |
# 		---------------------------------------------------------------------------------------------------------------
# 		| PHY261 | Biophysics                      | 12:00 AM | Room 1: N224 | Berhan , Ashraf Elshrief     |
# 		---------------------------------------------------------------------------------------------------------------
# 		| MAT231 | Probability and Statistics      | 12:00 AM | Room 1: NG24 | Mahmoud Hamed , Mohamed Ghetas      |
# 		---------------------------------------------------------------------------------------------------------------
#
# 		Thursday
# 		---------------------------------------------------------------------------------------------------------------
# 		| CSE112 | Algorithms                      | 3:00 PM | Room 1: N224 | Mohamed Ghetas , Mahmoud Safwat      |
# 		---------------------------------------------------------------------------------------------------------------
# 		| CSE014 | Structured Programming          | 3:00 PM | Room 1: I001 | Manar Elshazly , Mohamed Amir      |
# 		---------------------------------------------------------------------------------------------------------------
#
# Week 2
# ------
#
# 		Saturday
# 		---------------------------------------------------------------------------------------------------------------
# 		| CSE015 | Object Oriented Programming     | 3:00 PM | Room 1: NG24 | Mahmoud Safwat , Mohamed Amir      |
# 		---------------------------------------------------------------------------------------------------------------
#
# 		Sunday
# 		---------------------------------------------------------------------------------------------------------------
# 		| CSE383 | Computer Vision                 | 12:00 AM | Room 1: J302 | Samy Ghoniem , Radwa        |
# 		---------------------------------------------------------------------------------------------------------------
# 		| MAT123 | Mechanics                       | 3:00 PM | Room 1: J204 | Ahmed Heikal , Ibrahim Attia       |
# 		---------------------------------------------------------------------------------------------------------------
# 		| CSE273 | Parallel and Distributed Systems | 3:00 PM | Room 1: Q100 | Mohamed Ghetas , Manar Elshazly      |
# 		---------------------------------------------------------------------------------------------------------------
#
# 		Tuesday
# 		---------------------------------------------------------------------------------------------------------------
# 		| AIE111 | Artificial intelligence         | 12:00 AM | Room 1: I001 | Mohamed Abdelaziz , Ahmed Nader   |
# 		---------------------------------------------------------------------------------------------------------------
# 		| AIE121 | Machine Learning                | 3:00 PM | Room 1: N147 | Shaker Elsappagh , Manar Elshazly    |
# 		---------------------------------------------------------------------------------------------------------------
# 		| CSE272 | Embedded Systems                | 3:00 PM | Room 1: J201 | Ashraf Elshrief , Kariem     |
# 		---------------------------------------------------------------------------------------------------------------
#
# 		Wednesday
# 		---------------------------------------------------------------------------------------------------------------
# 		| CSE221 | Database Systems                | 12:00 AM | Room 1: J204 | Shaker Elsappagh , Samy Ghoniem    |
# 		---------------------------------------------------------------------------------------------------------------
# 		| AIE343 | Text Mining                     | 3:00 PM | Room 1: J301 | Manar Elshazly , Radwa      |
# 		---------------------------------------------------------------------------------------------------------------
# 		| AIE323 | Data Mining                     | 3:00 PM | Room 1: N247 | Mohamed Abdelaziz , Sameh Basha   |
# 		---------------------------------------------------------------------------------------------------------------
# 		| PHY232 | Modern physics                  | 3:00 PM | Room 1: J201 | Mohamed Emam Ismail , Mahmoud Hamed |
# 		---------------------------------------------------------------------------------------------------------------
#
# 		Thursday
# 		---------------------------------------------------------------------------------------------------------------
# 		| MAT121 | Dynamics                        | 12:00 AM | Room 1: N247 | Ahmed Hazem , Ahmed Nader         |
# 		---------------------------------------------------------------------------------------------------------------
# 		| CSE243 | Secure Programming              | 12:00 AM | Room 1: J302 | Mohamed Abdelaziz , Berhan   |
# 		---------------------------------------------------------------------------------------------------------------
